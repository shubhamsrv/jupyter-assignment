# %%
Todays task :
    q1 : Try to print a prime number in between 1 to 1000
    q2 : Try to write a function which  is equivalent  to print function in python
    q3 : Try to write a function which is a replica of list append , extend and pop function 
    q4 : Try to write a lambda function which can return a concatination of all the string that we will pass
    q5 : Try to write a lambda function which can return list of square of all the data between 1-100 
    q6 : Try to write a 10 Different different example of lambda function with a choice of your taks 
    q7 : Try to wwrite a funtion whihc can perform a read operation from .txt file 
        
        shivan@ineuron.ai
        sudhashu@ineuron.ai

# %%
# q1 Try to print a prime number in between 1 to 1000
k = []
for i in range(2,1000):
    if (i==2):
        print(i, "is a prime number")
    if (i>2):
        for j in range(2, i):
            if i%j==0:
                break
        else:
            print(i, "is  a prime")
# Out:
# 2 is a prime number
# 3 is  a prime
# 5 is  a prime
# 7 is  a prime
# 11 is  a prime
# 13 is  a prime
# 17 is  a prime
# 19 is  a prime
# 23 is  a prime
# 29 is  a prime
# 31 is  a prime
# 37 is  a prime
# 41 is  a prime
# 43 is  a prime
# 47 is  a prime
# 53 is  a prime
# 59 is  a prime
# 61 is  a prime
# 67 is  a prime
# 71 is  a prime
# 73 is  a prime
# 79 is  a prime
# 83 is  a prime
# 89 is  a prime
# 97 is  a prime
# 101 is  a prime
# 103 is  a prime
# 107 is  a prime
# 109 is  a prime
# 113 is  a prime
# 127 is  a prime
# 131 is  a prime
# 137 is  a prime
# 139 is  a prime
# 149 is  a prime
# 151 is  a prime
# 157 is  a prime
# 163 is  a prime
# 167 is  a prime
# 173 is  a prime
# 179 is  a prime
# 181 is  a prime
# 191 is  a prime
# 193 is  a prime
# 197 is  a prime
# 199 is  a prime
# 211 is  a prime
# 223 is  a prime
# 227 is  a prime
# 229 is  a prime
# 233 is  a prime
# 239 is  a prime
# 241 is  a prime
# 251 is  a prime
# 257 is  a prime
# 263 is  a prime
# ...

# %%
#q2: try to write a function which is equivalent to print function in python
def print_fun(a): 
    import sys
    return sys.stdout.write(a)
a = "hello shubham"
print_fun(a)
# Out:
# hello shubham

# %%
#q3: try to write a function which is replica of list append, extend and pop function
j = [1,2]
i =[4,5,6]
def list_append(j , i):
    j = j + [i]
    return j
        
list_append(j,i)  


x = [1,2,3]
y = [4,5,6]
def extending_func(x, y):
    x[len(x):] = y
    return x

extending_func(x,y)
a = [1,2,3,4,5]
def pop_item(a):
    a[:] = a[:-1]
    return a
pop_item(a)
# Out:
# [1, 2, 3, 4]

# %%
#q4: try to write a lambda function which can return a concatenation of all the string that we will pass

l1 = lambda *x: ' '.join([i for i in x])
l1("shub,","ravi","came","to", "playstore")
# Out:
# 'shub, ravi came to playstore'

# %%
#q5: try to write a lambda which can return list of square of all the data between 1-100
l1 = lambda *x: [i**2 for i in x]
for i in range(2,100):
    print(l1(i))
# Out:
# [4]
# [9]
# [16]
# [25]
# [36]
# [49]
# [64]
# [81]
# [100]
# [121]
# [144]
# [169]
# [196]
# [225]
# [256]
# [289]
# [324]
# [361]
# [400]
# [441]
# [484]
# [529]
# [576]
# [625]
# [676]
# [729]
# [784]
# [841]
# [900]
# [961]
# [1024]
# [1089]
# [1156]
# [1225]
# [1296]
# [1369]
# [1444]
# [1521]
# [1600]
# [1681]
# [1764]
# [1849]
# [1936]
# [2025]
# [2116]
# [2209]
# [2304]
# [2401]
# [2500]
# [2601]
# [2704]
# [2809]
# [2916]
# [3025]
# [3136]
# [3249]
# [3364]
# [3481]
# [3600]
# [3721]
# [3844]
# [3969]
# [4096]
# [4225]
# [4356]
# [4489]
# [4624]
# [4761]
# [4900]
# [5041]
# [5184]
# [5329]
# [5476]
# [5625]
# [5776]
# [5929]
# [6084]
# [6241]
# [6400]
# [6561]
# [6724]
# [6889]
# [7056]
# [7225]
# [7396]
# [7569]
# [7744]
# [7921]
# [8100]
# [8281]
# [8464]
# [8649]
# [8836]
# [9025]
# [9216]
# [9409]
# [9604]
# [9801]

# %%
#q6: try to write a 10 diffrent example of lambda function with a choice of your tasks
b = lambda *a:a
a = [1,5,3,8,4,2,9,7]
b(a)

n = lambda a, b : a+b
(a,b) =(5,8)
n(a,b)

c= lambda*x: [i**3 for i in x]
c(3,7,4,9)
 
d = lambda*x: ' '.join([i for i in x])

d("ram","shyam", "hari", "triyambkam")

e = lambda x: x.startswith('B')
e('Bob')


x='one'
y='apple'
f = lambda x, y: x+ " " +y 
f(x,y)
# Out:
# 'one apple'

# %%
f = lambda *x,y:[y+[i] for i in x]
x=(1,2,4,5,7,8)
y =[0]
f(x, y)

# %%
#q7: try to write a function which can perform a read operation from .txt file
def read_file(path):
    with open(path) as f:
        lines = f.readlines()
    return lines

path = 'readme.txt'
read_file(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-93d960aa4314> in <module>
#       6
#       7 path = 'readme.txt'
# ----> 8 read_file(path)
#
# <ipython-input-8-93d960aa4314> in read_file(path)
#       1 #q7: try to write a function which can perform a read operation from .txt file
#       2 def read_file(path):
# ----> 3     with open(path) as f:
#       4         lines = f.readlines()
#       5     return lines
#
# FileNotFoundError: [Errno 2] No such file or directory: 'readme.txt'
